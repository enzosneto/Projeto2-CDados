# %% [markdown]
# ## Projeto 2 - Ciência dos Dados

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lendo o banco de dados
data_0 = pd.read_csv("data.csv")

# %%
# Rodando as primeiras 5 linhas do banco de dados
data_0.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
# Filtrando as colunas
data = data_0.loc[:,["song_title", "artist", "tempo", "target","speechiness", "loudness", "energy", "instrumentalness", "duration_ms", "danceability", "acousticness", "key"]]

# %%
# Rodando as primeiras linhas depois de filtrar
data.head()
# Out:
#        song_title            artist    tempo  target  speechiness  loudness  \
# 0        Mask Off            Future  150.062       1       0.4310    -8.795
# 1         Redbone  Childish Gambino  160.083       1       0.0794   -10.401
# 2    Xanny Family            Future   75.044       1       0.2890    -7.148
# 3  Master Of None       Beach House   86.468       1       0.0261   -15.236
# 4  Parallel Lines       Junior Boys  174.004       1       0.0694   -11.648
#
#    energy  instrumentalness  duration_ms  danceability  acousticness  key
# 0   0.434          0.021900       204600         0.833        0.0102    2
# 1   0.359          0.006110       326933         0.743        0.1990    1
# 2   0.412          0.000234       185707         0.838        0.0344    2
# 3   0.338          0.510000       199413         0.494        0.6040    5
# 4   0.561          0.512000       392893         0.678        0.1800    5

# %%
# Substituindo os códigos números pelas respectivas notas na coluna "key"
data['key'] = data['key'].astype('category')
data['key'].cat.categories = ['C', 'C#', 'D','D#', 'E','F','F#','G','G#','A','A#','B',]
data.head()
# Out:
#        song_title            artist    tempo  target  speechiness  loudness  \
# 0        Mask Off            Future  150.062       1       0.4310    -8.795
# 1         Redbone  Childish Gambino  160.083       1       0.0794   -10.401
# 2    Xanny Family            Future   75.044       1       0.2890    -7.148
# 3  Master Of None       Beach House   86.468       1       0.0261   -15.236
# 4  Parallel Lines       Junior Boys  174.004       1       0.0694   -11.648
#
#    energy  instrumentalness  duration_ms  danceability  acousticness key
# 0   0.434          0.021900       204600         0.833        0.0102   D
# 1   0.359          0.006110       326933         0.743        0.1990  C#
# 2   0.412          0.000234       185707         0.838        0.0344   D
# 3   0.338          0.510000       199413         0.494        0.6040   F
# 4   0.561          0.512000       392893         0.678        0.1800   F

# %%
data_hit = data.loc[data['target']==1]
data_hit
# Out:
#             song_title            artist    tempo  target  speechiness  \
# 0             Mask Off            Future  150.062       1       0.4310
# 1              Redbone  Childish Gambino  160.083       1       0.0794
# 2         Xanny Family            Future   75.044       1       0.2890
# 3       Master Of None       Beach House   86.468       1       0.0261
# 4       Parallel Lines       Junior Boys  174.004       1       0.0694
# ...                ...               ...      ...     ...          ...
# 1015  6 In The Morning             Wiley  139.997       1       0.2950
# 1016  Skepta Interlude             Drake   86.733       1       0.2520
# 1017    Man Don't Care               Jme  140.008       1       0.2170
# 1018         Luke Cage         AJ Tracey  147.072       1       0.2710
# 1019          Shutdown            Skepta  107.039       1       0.3140
#
#       loudness  energy  instrumentalness  duration_ms  danceability  \
# ...

# %%
data_flop = data.loc[data['target']==0]
data_flop
# Out:
#                                 song_title            artist    tempo  target  \
# 1020                            My Old Man    Zac Brown Band  143.919       0
# 1021                          Losing Sleep       Chris Young   92.003       0
# 1022                     Sleep Without You       Brett Young   88.541       0
# 1023                              Yeah Boy  Kelsea Ballerini   88.965       0
# 1024                           Craving You      Thomas Rhett  104.986       0
# ...                                    ...               ...      ...     ...
# 2012   Like A Bitch - Kill The Noise Remix    Kill The Noise   74.976       0
# 2013                                 Candy    Dillon Francis  110.041       0
# 2014  Habit - Dack Janiels & Wenzday Remix          Rain Man  150.082       0
# 2015                         First Contact        Twin Moons  150.011       0
# 2016                    I Wanna Get Better         Bleachers  190.013       0
#
# ...

# %% [markdown]
# ## Análise exploratória inicial

# %% [markdown]
# ### Correlação entre as categorias das músicas

# %%
fig = plt.figure(figsize=(13, 5))

# Correlação entre energia e o volume
plt.subplot(121)
plt.scatter(data_hit.energy, data_hit.loudness, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Volume')
plt.title('Correlação entre energia e o volume')

# Correlação entre energia e dançabilidade
plt.subplot(122)
plt.scatter(data_flop.energy, data_flop.loudness, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Dançabilidade')
plt.title('Correlação entre energia e dançabilidade')

plt.tight_layout(1)
plt.show()

# %%
fig = plt.figure(figsize=(13, 5))

# Correlação entre energia e dançabilidade
plt.subplot(121)
plt.scatter(data.energy, data.danceability, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Dançabilidade')
plt.title('Correlação entre energia e dançabilidade')

# Correlação entre energia e o volume
plt.subplot(122)
plt.scatter(data.energy, data.loudness, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Volume')
plt.title('Correlação entre energia e o volume')

plt.tight_layout(1)
plt.show()

# %%
fig = plt.figure(figsize=(13, 5))

#Correlação entre energia e o acústica
plt.subplot(121)
plt.scatter(data.energy, data.acousticness, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Acústica')
plt.title('Correlação entre energia e acústica')

#Correlação entre energia e o instrumental
plt.subplot(122)
plt.scatter(data.energy, data.instrumentalness, c='green', alpha=0.4)
plt.xlabel('Energia')
plt.ylabel('Instrumental')
plt.title('Correlação entre energia e instrumental')

plt.tight_layout(1)
plt.show()

# %% [markdown]
# ### Histograma das categorias

# %%
plt.figure(figsize=(10,3))

plt.subplot(131)
fig = data.tempo.plot.hist(bins=15, title='Tempo', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.subplot(132)
fig = data.speechiness.plot.hist(bins=15, title='Speechiness', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.subplot(133)
fig = data.loudness.plot.hist(bins=15, title='Loudness', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.tight_layout(1)

# %%
plt.figure(figsize=(10,3))

plt.subplot(131)
fig = data.energy.plot.hist(bins=15, title='Energy', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.subplot(132)
fig = data.instrumentalness.plot.hist(bins=15, title='Instrumentalness', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.subplot(133)
fig = data.duration_ms.plot.hist(bins=15, title='Duration (ms)', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.tight_layout(1)

# %%
plt.figure(figsize=(10,3))

plt.subplot(131)
fig = data.danceability.plot.hist(bins=15, title='Danceability', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.subplot(132)
fig = data.acousticness.plot.hist(bins=15, title='Acousticness', alpha=0.9, edgecolor='white')
plt.ylabel('Frequência')

plt.tight_layout(1)
